# %%
from datetime import datetime
from pathlib import Path
import sklearn
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
import numpy as np
import pandas as pd

print(sklearn.__version__)
# Out:
# 1.5.2

# %%
ACTIVITY_TAG_MAP = {
    1: "fall_forward_hands",
    2: "fall_forward_knees",
    3: "fall_backwards",
    4: "fall_sideward",
    5: "fall_sitting_chair",
    6: "walking",
    7: "standing",
    8: "sitting",
    9: "picking_object",
    10: "jumping",
    11: "laying",
}

# %%
def get_metrics(expected_y, predicted_y):
    return {
        "recall": metrics.recall_score(expected_y, predicted_y),
        "f1": metrics.f1_score(expected_y, predicted_y),
        "precision": metrics.precision_score(expected_y, predicted_y),
        "accuracy": metrics.accuracy_score(expected_y, predicted_y),
    }

# %%
models = {
    "KNN": {
        "estimator": KNN(metric="euclidean"),
        "params": {
            "n_neighbors": [3, 5, 7, 9, 11],
            "weights": ["uniform", "distance"],
        },
    },
    "RF": {
        "estimator": RandomForestClassifier(
            criterion="gini", oob_score=metrics.recall_score
        ),
        "params": {
            "n_estimators": [50, 100, 200],
            "max_features": ["sqrt", "log2"],
        },
    },
    # https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html
    "MLP": {
        "estimator": MLPClassifier(solver="adam", max_iter=1000),
        "params": {
            # "max_iter": [100, 500, 1000],  # number of epochs
            "hidden_layer_sizes": [
                (8,),
                (8, 8),
                (8, 16),
                (8, 32),
                (8, 64),
                (8, 128),
                (16,),
                (16, 8),
                (16, 16),
                (16, 32),
                (16, 64),
                (16, 128),
                (32,),
                (32, 8),
                (32, 16),
                (32, 32),
                (32, 64),
                (32, 128),
                (64,),
                (64, 8),
                (64, 16),
                (64, 32),
                (64, 64),
                (64, 128),
                (128,),
                (128, 8),
                (128, 16),
                (128, 32),
                (128, 64),
                (128, 128),
            ],
        },
    },
    "SVM": {
        "estimator": SVC(),
        "params": {"class_weight": [{0: 1, 1: 10}, {0: 1, 1: 20}, {0: 1, 1: 1}]},
    },
}

algorithm_options = ["KNN", "RF", "MLP", "SVM"]
# algorithm = "KNN"

# %%
datasets_path = Path.cwd() / "datasets"
columns_not_used_for_training = ["Timestamp", "Subject", "Trial", "Activity", "Tag"]

skf = StratifiedKFold(n_splits=5, shuffle=True)

# %%
for algorithm in algorithm_options:
    model = models[algorithm]

    gs_cv_model = GridSearchCV(
        model["estimator"],
        model["params"],
        scoring="recall",
        n_jobs=-1,
        cv=2,
    )
    output_dir_name = (
        "results/" + datetime.today().strftime("%Y-%m-%d_%H-%M_") + algorithm
    )

    output_dir = Path.cwd() / output_dir_name

    output_dir.mkdir(exist_ok=True, parents=True)


    training_info_output_file = output_dir / "_training_info.txt"


    training_info_output_file.write_text(f"{algorithm} - {model['params']}")


    output_file_path = output_dir / f"{algorithm}_training_results.csv"

    output_file = open(output_file_path, mode="w", encoding="utf-8")
    output_file.write(
        "sensor_position,features_domain,n_fold,recall,f1,precision,accuracy,best_params\n"
    )

    mistakes_file_path = output_dir / f"{algorithm}_mistakes.csv"
    mistakes_file = open(mistakes_file_path, mode="w", encoding="utf-8")
    mistakes_file.write(
        "sensor_position,features_domain,n_fold,"
        + ",".join(ACTIVITY_TAG_MAP.values())
        + "\n"
    )

    for dataset in datasets_path.iterdir():

        data = pd.read_csv(dataset, header=0).dropna()
        data = data[data["Tag"] != 20]

        X = data.drop(columns=columns_not_used_for_training)
        # X = data

        print(X.shape)


        y = pd.DataFrame(
            {"is_fall": [0 if row > 5 else 1 for row in data["Tag"]]}
        ).values.reshape(
            -1,
        )


        print(y.shape)

        # print(data.iloc[0])
        # print(data.at[data.index[0], "Tag"])

        # continue


        n_fold = 0

        sensor_position, features_domain = dataset.name.rstrip("dataset.csv").split(
            "_", 1
        )


        features_domain = "both" if not features_domain else features_domain.rstrip("_")


        for train, test in skf.split(X, y):

            X_train, X_test = X.iloc[train], X.iloc[test]


            y_train, y_test = y[train], y[test]


            classifier = gs_cv_model.fit(X_train, y_train)


            prediction = classifier.predict(X_test)

            # print(prediction)


            fold_metrics = get_metrics(y_test, prediction)

            output_file.write(
                f"{sensor_position},{features_domain},{n_fold},{fold_metrics['recall']},"
                f"{fold_metrics['f1']},{fold_metrics['precision']},{fold_metrics['accuracy']},\"{classifier.best_params_}\"\n"
            )

            print(
                f"{sensor_position},{features_domain},{n_fold},{fold_metrics['recall']},"
                f"{fold_metrics['f1']},{fold_metrics['precision']},{fold_metrics['accuracy']},\"{classifier.best_params_}\"\n"
            )

            fold_mistakes = {i: 0 for i in range(1, 12)}

            for i in range(len(prediction)):
                if prediction[i] != y_test[i]:
                    fold_mistakes[data.at[data.index[test[i]], "Tag"]] += 1

            mistakes_file.write(
                f"{sensor_position},{features_domain},{n_fold},"
                f"{','.join(str(value) for value in fold_mistakes.values())}\n"
            )

            print(
                f"{sensor_position},{features_domain},{n_fold},"
                f"{','.join(str(value) for value in fold_mistakes.values())}\n"
            )


            print(metrics.confusion_matrix(y_test, prediction))

            n_fold += 1


    output_file.close()
    mistakes_file.close()


# print(metrics.classification_report(expected_y, predicted_y))
# Out:
# (32113, 108)
# (32113,)
# Ankle,both,0,0.04712041884816754,0.0743801652892562,0.17647058823529413,0.9651253308422856,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,both,0,36,34,39,24,49,28,0,2,2,4,6
#
# [[6190   42]
#  [ 182    9]]
# Ankle,both,1,0.06282722513089005,0.09302325581395349,0.1791044776119403,0.9635684259691732,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,both,1,22,29,45,39,44,25,4,2,4,13,7
#
# [[6177   55]
#  [ 179   12]]
# Ankle,both,2,0.07329842931937172,0.11067193675889328,0.22580645161290322,0.9649696403549743,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,both,2,36,34,38,21,48,22,1,1,2,15,7
#
# [[6184   48]
#  [ 177   14]]
# Ankle,both,3,0.07329842931937172,0.11155378486055777,0.23333333333333334,0.9652756150731859,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,both,3,40,33,37,26,41,26,1,3,0,11,5
#
# [[6185   46]
#  [ 177   14]]
# Ankle,both,4,0.07853403141361257,0.12096774193548387,0.2631578947368421,0.9660541887262535,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,both,4,27,37,37,35,40,25,1,0,2,9,5
#
# [[6189   42]
#  [ 176   15]]
# (32113, 36)
# (32113,)
# Ankle,frequency,0,0.06282722513089005,0.09022556390977443,0.16,0.9623229020706835,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,frequency,0,29,37,35,25,53,37,1,1,1,20,3
#
# [[6169   63]
#  [ 179   12]]
# Ankle,frequency,1,0.06806282722513089,0.09961685823754789,0.18571428571428572,0.963412735481862,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,frequency,1,32,30,48,35,33,30,3,4,0,13,7
#
# [[6175   57]
#  [ 178   13]]
# Ankle,frequency,2,0.07329842931937172,0.10526315789473684,0.18666666666666668,0.9629456640199284,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,frequency,2,34,29,45,29,40,37,1,0,3,13,7
#
# [[6171   61]
#  [ 177   14]]
# Ankle,frequency,3,0.07329842931937172,0.10852713178294573,0.208955223880597,0.9641856119588913,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,frequency,3,37,34,34,23,49,29,1,0,0,16,7
#
# [[6178   53]
#  [ 177   14]]
# Ankle,frequency,4,0.03664921465968586,0.05622489959839357,0.1206896551724138,0.9634070383058237,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,frequency,4,29,35,35,37,48,29,2,3,1,12,4
#
# [[6180   51]
#  [ 184    7]]
# (32117, 72)
# (32117,)
# Ankle,time,0,0.225130890052356,0.30824372759856633,0.48863636363636365,0.9699564134495642,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,time,0,21,22,39,25,41,14,4,3,5,11,8
#
# [[6188   45]
#  [ 148   43]]
# Ankle,time,1,0.21465968586387435,0.311787072243346,0.5694444444444444,0.9718244084682441,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,time,1,22,29,36,25,38,14,3,3,1,4,6
#
# [[6202   31]
#  [ 150   41]]
# Ankle,time,2,0.2879581151832461,0.3819444444444444,0.5670103092783505,0.9722870932586019,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,time,2,29,26,21,16,44,19,2,0,2,6,13
#
# [[6190   42]
#  [ 136   55]]
# Ankle,time,3,0.27225130890052357,0.37545126353790614,0.6046511627906976,0.973065545695158,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,time,3,22,29,25,30,33,19,3,1,1,6,4
#
# [[6198   34]
#  [ 139   52]]
# Ankle,time,4,0.2617801047120419,0.35335689045936397,0.5434782608695652,0.9715086408220458,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Ankle,time,4,25,18,35,27,36,14,4,2,2,10,10
#
# [[6190   42]
#  [ 141   50]]
# (32113, 108)
# (32113,)
# Belt,both,0,0.1256544502617801,0.17266187050359713,0.27586206896551724,0.9641911879184182,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,both,0,38,27,37,29,36,29,2,2,1,27,2
#
# [[6169   63]
#  [ 167   24]]
# Belt,both,1,0.193717277486911,0.25,0.3523809523809524,0.9654367118169079,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,both,1,33,32,32,23,34,24,5,2,2,26,9
#
# [[6164   68]
#  [ 154   37]]
# Belt,both,2,0.18324607329842932,0.24475524475524477,0.3684210526315789,0.9663708547407753,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,both,2,26,26,36,29,39,23,4,1,2,26,4
#
# [[6172   60]
#  [ 156   35]]
# Belt,both,3,0.20418848167539266,0.27956989247311825,0.4431818181818182,0.9687013391466833,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,both,3,30,30,19,32,41,21,6,3,0,13,6
#
# [[6182   49]
#  [ 152   39]]
# Belt,both,4,0.1518324607329843,0.2078853046594982,0.32954545454545453,0.9655870445344129,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,both,4,25,30,40,31,36,21,4,9,2,20,3
#
# [[6172   59]
#  [ 162   29]]
# (32113, 36)
# (32113,)
# Belt,frequency,0,0.16230366492146597,0.2271062271062271,0.3780487804878049,0.9671493071773315,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,frequency,0,34,32,31,27,36,18,5,2,1,18,7
#
# [[6181   51]
#  [ 160   31]]
# Belt,frequency,1,0.14659685863874344,0.19718309859154928,0.3010752688172043,0.9645025688930406,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,frequency,1,36,31,36,21,39,26,6,1,1,25,6
#
# [[6167   65]
#  [ 163   28]]
# Belt,frequency,2,0.14136125654450263,0.19852941176470587,0.3333333333333333,0.9660594737661529,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,frequency,2,29,28,43,31,33,25,1,4,1,20,3
#
# [[6178   54]
#  [ 164   27]]
# Belt,frequency,3,0.20418848167539266,0.2698961937716263,0.3979591836734694,0.9671441918405481,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,frequency,3,19,28,35,24,46,23,3,1,1,23,8
#
# [[6172   59]
#  [ 152   39]]
# Belt,frequency,4,0.18324607329842932,0.23178807947019867,0.3153153153153153,0.9638741824976643,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,frequency,4,30,28,22,41,35,37,1,3,2,28,5
#
# [[6155   76]
#  [ 156   35]]
# (32117, 72)
# (32117,)
# Belt,time,0,0.2774869109947644,0.38545454545454544,0.6309523809523809,0.973692403486924,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,time,0,22,24,32,23,37,6,4,2,4,10,5
#
# [[6202   31]
#  [ 138   53]]
# Belt,time,1,0.2198952879581152,0.31343283582089554,0.5454545454545454,0.9713574097135741,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,time,1,29,35,30,23,32,16,1,0,1,10,7
#
# [[6198   35]
#  [ 149   42]]
# Belt,time,2,0.2670157068062827,0.37362637362637363,0.6219512195121951,0.9733769266697805,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,time,2,28,29,23,29,31,10,0,2,5,8,6
#
# [[6201   31]
#  [ 140   51]]
# Belt,time,3,0.24607329842931938,0.34558823529411764,0.5802469135802469,0.9722870932586019,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,time,3,28,32,32,26,26,13,2,1,2,13,3
#
# [[6198   34]
#  [ 144   47]]
# Belt,time,4,0.2617801047120419,0.3546099290780142,0.5494505494505495,0.971664331309357,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Belt,time,4,30,22,27,21,41,14,4,2,1,18,2
#
# [[6191   41]
#  [ 141   50]]
# (28324, 540)
# (28324,)
# full,both,0,0.45294117647058824,0.5877862595419847,0.8369565217391305,0.9809355692850839,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# full,both,0,12,21,21,17,22,0,5,0,0,3,7
#
# [[5480   15]
#  [  93   77]]
# full,both,1,0.4294117647058823,0.5703125,0.8488372093023255,0.9805825242718447,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,both,1,20,22,16,21,18,3,5,0,1,0,4
#
# [[5482   13]
#  [  97   73]]
# full,both,2,0.4294117647058823,0.5637065637065637,0.8202247191011236,0.9800529567519859,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,both,2,24,16,18,13,26,4,2,0,1,1,8
#
# [[5479   16]
#  [  97   73]]
# full,both,3,0.4678362573099415,0.6153846153846154,0.898876404494382,0.9823477493380406,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,both,3,22,20,15,13,21,2,1,0,1,1,4
#
# [[5485    9]
#  [  91   80]]
# full,both,4,0.4117647058823529,0.5405405405405406,0.7865168539325843,0.9789901129943502,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,both,4,18,16,21,16,29,8,0,1,0,2,8
#
# [[5475   19]
#  [ 100   70]]
# (32113, 36)
# (32113,)
# full,frequency,0,0.1256544502617801,0.16783216783216784,0.25263157894736843,0.9629456640199284,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# full,frequency,0,34,35,28,29,41,34,7,5,0,19,6
#
# [[6161   71]
#  [ 167   24]]
# full,frequency,1,0.18848167539267016,0.25,0.3711340206185567,0.9663708547407753,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# full,frequency,1,31,31,42,21,30,25,9,5,0,17,5
#
# [[6171   61]
#  [ 155   36]]
# full,frequency,2,0.13089005235602094,0.17543859649122806,0.26595744680851063,0.963412735481862,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,frequency,2,27,30,34,28,47,32,9,2,1,16,9
#
# [[6163   69]
#  [ 166   25]]
# full,frequency,3,0.14659685863874344,0.19649122807017544,0.2978723404255319,0.9643413266895048,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# full,frequency,3,31,35,27,32,38,26,13,4,0,15,8
#
# [[6165   66]
#  [ 163   28]]
# full,frequency,4,0.13089005235602094,0.17482517482517482,0.2631578947368421,0.9632513235752103,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# full,frequency,4,27,29,40,32,38,27,7,5,0,20,11
#
# [[6161   70]
#  [ 166   25]]
# (32117, 72)
# (32117,)
# full,time,0,0.1099476439790576,0.16535433070866143,0.3333333333333333,0.9669987546699875,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,time,0,31,31,29,37,42,17,3,5,0,10,7
#
# [[6191   42]
#  [ 170   21]]
# full,time,1,0.15706806282722513,0.22988505747126436,0.42857142857142855,0.9687110834371109,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,time,1,31,33,30,24,43,14,4,5,0,10,7
#
# [[6193   40]
#  [ 161   30]]
# full,time,2,0.15706806282722513,0.21897810218978103,0.3614457831325301,0.9666822357153978,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# full,time,2,27,25,44,28,37,19,7,2,0,18,7
#
# [[6179   53]
#  [ 161   30]]
# full,time,3,0.13089005235602094,0.18315018315018314,0.3048780487804878,0.9652810213295968,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# full,time,3,26,36,43,31,30,19,7,5,4,15,7
#
# [[6175   57]
#  [ 166   25]]
# full,time,4,0.11518324607329843,0.16666666666666666,0.3013698630136986,0.9657480927915304,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# full,time,4,31,33,33,29,43,17,7,4,0,17,6
#
# [[6181   51]
#  [ 169   22]]
# (32113, 108)
# (32113,)
# Neck,both,0,0.2094240837696335,0.25,0.31007751937984496,0.962634283045306,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,both,0,32,28,34,29,28,15,7,3,3,53,8
#
# [[6143   89]
#  [ 151   40]]
# Neck,both,1,0.16753926701570682,0.2222222222222222,0.32989690721649484,0.9651253308422856,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,both,1,28,24,41,24,42,11,2,0,4,47,1
#
# [[6167   65]
#  [ 159   32]]
# Neck,both,2,0.17801047120418848,0.23367697594501718,0.34,0.9652810213295968,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,both,2,35,33,30,22,37,13,4,2,4,38,5
#
# [[6166   66]
#  [ 157   34]]
# Neck,both,3,0.17801047120418848,0.24548736462093862,0.3953488372093023,0.9674556213017751,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# Neck,both,3,29,24,36,26,42,6,5,3,3,29,6
#
# [[6179   52]
#  [ 157   34]]
# Neck,both,4,0.225130890052356,0.2783171521035599,0.3644067796610169,0.9652756150731859,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,both,4,24,34,34,15,41,13,1,4,3,46,8
#
# [[6156   75]
#  [ 148   43]]
# (32113, 36)
# (32113,)
# Neck,frequency,0,0.20418848167539266,0.2484076433121019,0.3170731707317073,0.9632570449945508,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,frequency,0,30,36,32,21,33,16,4,1,2,48,13
#
# [[6148   84]
#  [ 152   39]]
# Neck,frequency,1,0.17277486910994763,0.23655913978494625,0.375,0.966837926202709,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,frequency,1,28,33,33,27,37,8,3,1,2,34,7
#
# [[6177   55]
#  [ 158   33]]
# Neck,frequency,2,0.17801047120418848,0.22818791946308725,0.3177570093457944,0.9641911879184182,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,frequency,2,32,34,33,19,39,9,3,4,4,42,11
#
# [[6159   73]
#  [ 157   34]]
# Neck,frequency,3,0.18848167539267016,0.23452768729641693,0.3103448275862069,0.9634070383058237,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,frequency,3,28,25,40,22,40,11,6,2,2,56,3
#
# [[6151   80]
#  [ 155   36]]
# Neck,frequency,4,0.2198952879581152,0.27631578947368424,0.37168141592920356,0.9657427592650265,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,frequency,4,29,20,38,23,39,9,5,3,9,41,4
#
# [[6160   71]
#  [ 149   42]]
# (32117, 72)
# (32117,)
# Neck,time,0,0.31413612565445026,0.41237113402061853,0.6,0.9733810709838107,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,time,0,20,23,31,19,38,4,5,0,5,18,8
#
# [[6193   40]
#  [ 131   60]]
# Neck,time,1,0.24607329842931938,0.3298245614035088,0.5,0.9702677459526775,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,time,1,34,26,33,18,33,1,2,1,3,36,4
#
# [[6186   47]
#  [ 144   47]]
# Neck,time,2,0.3403141361256545,0.40625,0.5038759689922481,0.9704188074108672,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,time,2,25,31,26,24,20,2,5,1,5,43,8
#
# [[6168   64]
#  [ 126   65]]
# Neck,time,3,0.2617801047120419,0.3401360544217687,0.4854368932038835,0.9697960454616223,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,time,3,23,30,33,22,33,2,6,1,4,34,6
#
# [[6179   53]
#  [ 141   50]]
# Neck,time,4,0.2879581151832461,0.3806228373702422,0.5612244897959183,0.9721314027712906,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Neck,time,4,28,21,32,17,38,6,3,3,2,18,11
#
# [[6189   43]
#  [ 136   55]]
# (28324, 108)
# (28324,)
# RightPocket,both,0,0.35294117647058826,0.4411764705882353,0.5882352941176471,0.9731685789938217,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# RightPocket,both,0,19,22,21,20,28,8,4,4,1,23,2
#
# [[5453   42]
#  [ 110   60]]
# RightPocket,both,1,0.3411764705882353,0.43609022556390975,0.6041666666666666,0.9735216240070609,"{'n_neighbors': 5, 'weights': 'distance'}"
#
# RightPocket,both,1,26,21,17,29,19,5,1,1,3,20,8
#
# [[5457   38]
#  [ 112   58]]
# RightPocket,both,2,0.2647058823529412,0.3543307086614173,0.5357142857142857,0.9710503089143866,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# RightPocket,both,2,21,26,27,21,30,8,6,1,0,19,5
#
# [[5456   39]
#  [ 125   45]]
# RightPocket,both,3,0.28654970760233917,0.3643122676579926,0.5,0.9698146513680495,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# RightPocket,both,3,22,25,21,20,34,8,4,2,3,28,4
#
# [[5445   49]
#  [ 122   49]]
# RightPocket,both,4,0.32941176470588235,0.398576512455516,0.5045045045045045,0.970162429378531,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# RightPocket,both,4,26,26,21,19,22,6,2,2,5,32,8
#
# [[5439   55]
#  [ 114   56]]
# (28324, 36)
# (28324,)
# RightPocket,frequency,0,0.3058823529411765,0.37142857142857144,0.4727272727272727,0.9689320388349515,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# RightPocket,frequency,0,23,25,21,25,24,11,7,1,3,30,6
#
# [[5437   58]
#  [ 118   52]]
# RightPocket,frequency,1,0.3176470588235294,0.4122137404580153,0.5869565217391305,0.9728155339805825,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# RightPocket,frequency,1,32,25,21,18,20,3,2,0,4,26,3
#
# [[5457   38]
#  [ 116   54]]
# RightPocket,frequency,2,0.32941176470588235,0.3916083916083916,0.4827586206896552,0.9692850838481907,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# RightPocket,frequency,2,24,25,18,19,28,17,3,8,3,24,5
#
# [[5435   60]
#  [ 114   56]]
# RightPocket,frequency,3,0.3157894736842105,0.4,0.5454545454545454,0.9714033539276258,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# RightPocket,frequency,3,18,21,22,28,28,10,4,2,2,23,4
#
# [[5449   45]
#  [ 117   54]]
# RightPocket,frequency,4,0.3176470588235294,0.4122137404580153,0.5869565217391305,0.9728107344632768,"{'n_neighbors': 5, 'weights': 'uniform'}"
#
# RightPocket,frequency,4,21,27,18,27,23,2,2,1,2,23,8
#
# [[5456   38]
#  [ 116   54]]
# (28326, 72)
# (28326,)
# RightPocket,time,0,0.38596491228070173,0.4981132075471698,0.7021276595744681,0.9765266501941405,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# RightPocket,time,0,30,20,17,13,25,8,2,1,4,8,5
#
# [[5467   28]
#  [ 105   66]]
# RightPocket,time,1,0.40588235294117647,0.5267175572519084,0.75,0.9781112091791704,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# RightPocket,time,1,21,21,17,19,23,4,3,1,4,6,5
#
# [[5472   23]
#  [ 101   69]]
# RightPocket,time,2,0.3764705882352941,0.4794007490636704,0.6597938144329897,0.9754633715798764,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# RightPocket,time,2,20,22,21,19,24,6,3,0,8,10,6
#
# [[5462   33]
#  [ 106   64]]
# RightPocket,time,3,0.36470588235294116,0.48249027237354086,0.7126436781609196,0.9765225066195939,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# RightPocket,time,3,30,19,19,19,21,4,5,2,5,5,4
#
# [[5470   25]
#  [ 108   62]]
# RightPocket,time,4,0.2823529411764706,0.41739130434782606,0.8,0.9763459841129744,"{'n_neighbors': 7, 'weights': 'distance'}"
#
# RightPocket,time,4,20,28,29,15,30,1,1,0,2,6,2
#
# [[5483   12]
#  [ 122   48]]
# (32113, 108)
# (32113,)
# Wrist,both,0,0.15706806282722513,0.20066889632107024,0.2777777777777778,0.9627899735326172,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,both,0,34,34,27,33,33,34,10,4,1,21,8
#
# [[6154   78]
#  [ 161   30]]
# Wrist,both,1,0.14136125654450263,0.18947368421052632,0.2872340425531915,0.964035497431107,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,both,1,29,30,43,28,34,24,13,4,1,19,6
#
# [[6165   67]
#  [ 164   27]]
# Wrist,both,2,0.18324607329842932,0.24305555555555555,0.36082474226804123,0.9660594737661529,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,both,2,25,33,29,28,41,29,7,5,0,16,5
#
# [[6170   62]
#  [ 156   35]]
# Wrist,both,3,0.16753926701570682,0.21052631578947367,0.2831858407079646,0.9626284646527562,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,both,3,26,35,32,30,36,30,8,6,1,25,11
#
# [[6150   81]
#  [ 159   32]]
# Wrist,both,4,0.1099476439790576,0.16600790513833993,0.3387096774193548,0.9671441918405481,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,both,4,33,28,38,26,45,18,4,4,0,13,2
#
# [[6190   41]
#  [ 170   21]]
# (32113, 36)
# (32113,)
# Wrist,frequency,0,0.1099476439790576,0.15498154981549817,0.2625,0.9643468784057294,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,frequency,0,29,37,30,31,43,24,7,5,0,13,10
#
# [[6173   59]
#  [ 170   21]]
# Wrist,frequency,1,0.18324607329842932,0.23411371237458195,0.32407407407407407,0.9643468784057294,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,frequency,1,28,28,31,27,42,27,10,4,0,21,11
#
# [[6159   73]
#  [ 156   35]]
# Wrist,frequency,2,0.14659685863874344,0.19112627986348124,0.27450980392156865,0.9631013545072397,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,frequency,2,30,28,42,31,32,25,10,8,2,23,6
#
# [[6158   74]
#  [ 163   28]]
# Wrist,frequency,3,0.14136125654450263,0.19148936170212766,0.2967032967032967,0.9644970414201184,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,frequency,3,26,38,37,25,38,26,7,4,1,20,6
#
# [[6167   64]
#  [ 164   27]]
# Wrist,frequency,4,0.1099476439790576,0.16470588235294117,0.328125,0.966832762379321,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# Wrist,frequency,4,36,29,35,30,40,23,10,0,0,6,4
#
# [[6188   43]
#  [ 170   21]]
# (32117, 72)
# (32117,)
# Wrist,time,0,0.16230366492146597,0.22545454545454546,0.36904761904761907,0.9668430884184309,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,time,0,30,31,39,17,43,22,4,3,0,16,8
#
# [[6180   53]
#  [ 160   31]]
# Wrist,time,1,0.16230366492146597,0.23484848484848486,0.4246575342465753,0.9685554171855542,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# Wrist,time,1,35,29,28,30,38,14,5,4,0,13,6
#
# [[6191   42]
#  [ 160   31]]
# Wrist,time,2,0.13089005235602094,0.19157088122605365,0.35714285714285715,0.9671493071773315,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,time,2,25,29,37,34,41,16,4,5,0,14,6
#
# [[6187   45]
#  [ 166   25]]
# Wrist,time,3,0.14136125654450263,0.19852941176470587,0.3333333333333333,0.9660594737661529,"{'n_neighbors': 3, 'weights': 'uniform'}"
#
# Wrist,time,3,31,27,37,30,39,14,13,4,0,17,6
#
# [[6178   54]
#  [ 164   27]]
# Wrist,time,4,0.18848167539267016,0.259927797833935,0.4186046511627907,0.9680834501011988,"{'n_neighbors': 3, 'weights': 'distance'}"
#
# Wrist,time,4,26,33,34,34,28,15,4,5,1,18,7
#
# [[6182   50]
#  [ 155   36]]
# (32113, 108)
# (32113,)
# Ankle,both,0,0.7015706806282722,0.7859237536656891,0.8933333333333333,0.9886345944262805,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,both,0,12,6,11,10,18,1,0,0,0,0,15
#
# [[6216   16]
#  [  57  134]]
# Ankle,both,1,0.6910994764397905,0.7833827893175074,0.9041095890410958,0.9886345944262805,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Ankle,both,1,10,2,12,13,22,0,0,0,0,0,14
#
# [[6218   14]
#  [  59  132]]
# Ankle,both,2,0.6858638743455497,0.7507163323782235,0.8291139240506329,0.9864549276039234,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Ankle,both,2,18,11,8,10,13,0,0,0,0,0,27
#
# [[6205   27]
#  [  60  131]]
# Ankle,both,3,0.6492146596858639,0.7469879518072289,0.8794326241134752,0.9869199626284646,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,both,3,16,6,11,6,28,0,0,1,0,0,16
#
# [[6214   17]
#  [  67  124]]
# Ankle,both,4,0.643979057591623,0.7409638554216867,0.8723404255319149,0.9866085331672376,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,both,4,15,11,14,14,14,0,1,0,0,0,17
#
# [[6213   18]
#  [  68  123]]
# (32113, 36)
# (32113,)
# Ankle,frequency,0,0.5759162303664922,0.6853582554517134,0.8461538461538461,0.9842752607815662,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,frequency,0,16,13,15,15,22,0,0,0,0,1,19
#
# [[6212   20]
#  [  81  110]]
# Ankle,frequency,1,0.6020942408376964,0.7165109034267912,0.8846153846153846,0.9858321656546785,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,frequency,1,21,5,17,12,21,0,0,0,0,0,15
#
# [[6217   15]
#  [  76  115]]
# Ankle,frequency,2,0.6020942408376964,0.7076923076923077,0.8582089552238806,0.9852094037054336,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Ankle,frequency,2,12,13,12,13,26,0,1,0,0,0,18
#
# [[6213   19]
#  [  76  115]]
# Ankle,frequency,3,0.6020942408376964,0.7033639143730887,0.8455882352941176,0.9848956711304889,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,frequency,3,15,10,15,14,22,0,0,0,0,0,21
#
# [[6210   21]
#  [  76  115]]
# Ankle,frequency,4,0.6020942408376964,0.7165109034267912,0.8846153846153846,0.9858299595141701,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,frequency,4,20,10,8,10,28,0,0,0,0,0,15
#
# [[6216   15]
#  [  76  115]]
# (32117, 72)
# (32117,)
# Ankle,time,0,0.6492146596858639,0.7469879518072289,0.8794326241134752,0.9869240348692403,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,time,0,12,8,20,8,19,0,1,0,0,0,16
#
# [[6216   17]
#  [  67  124]]
# Ankle,time,1,0.6649214659685864,0.7448680351906158,0.8466666666666667,0.9864570361145704,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,time,1,12,9,15,10,18,0,1,0,0,0,22
#
# [[6210   23]
#  [  64  127]]
# Ankle,time,2,0.6649214659685864,0.7650602409638554,0.900709219858156,0.9878561419897244,"{'max_features': 'log2', 'n_estimators': 200}"
#
# Ankle,time,2,12,8,7,10,27,1,0,0,0,0,13
#
# [[6218   14]
#  [  64  127]]
# Ankle,time,3,0.7172774869109948,0.7873563218390804,0.8726114649681529,0.9884789039389693,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Ankle,time,3,15,6,7,10,16,0,0,0,0,2,18
#
# [[6212   20]
#  [  54  137]]
# Ankle,time,4,0.7015706806282722,0.783625730994152,0.8874172185430463,0.9884789039389693,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Ankle,time,4,17,6,9,11,14,0,0,1,0,0,16
#
# [[6215   17]
#  [  57  134]]
# (32113, 108)
# (32113,)
# Belt,both,0,0.5340314136125655,0.6517571884984026,0.8360655737704918,0.9830297368830765,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Belt,both,0,20,15,16,18,20,0,1,0,0,2,17
#
# [[6212   20]
#  [  89  102]]
# Belt,both,1,0.5130890052356021,0.6533333333333333,0.8990825688073395,0.9838081893196325,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Belt,both,1,14,27,12,18,22,0,0,2,1,1,7
#
# [[6221   11]
#  [  93   98]]
# Belt,both,2,0.6073298429319371,0.7073170731707317,0.8467153284671532,0.9850537132181224,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Belt,both,2,12,27,12,11,13,0,0,0,2,2,17
#
# [[6211   21]
#  [  75  116]]
# Belt,both,3,0.612565445026178,0.72,0.8731343283582089,0.9858299595141701,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Belt,both,3,15,12,19,14,14,0,1,1,3,0,12
#
# [[6214   17]
#  [  74  117]]
# Belt,both,4,0.6178010471204188,0.7283950617283951,0.8872180451127819,0.9862971037060105,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Belt,both,4,12,9,11,13,28,0,1,0,0,2,12
#
# [[6216   15]
#  [  73  118]]
# (32113, 36)
# (32113,)
# Belt,frequency,0,0.4031413612565445,0.5441696113074205,0.8369565217391305,0.9799159271368519,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Belt,frequency,0,19,25,18,18,34,0,0,3,1,3,8
#
# [[6217   15]
#  [ 114   77]]
# Belt,frequency,1,0.5392670157068062,0.673202614379085,0.8956521739130435,0.9844309512688775,"{'max_features': 'log2', 'n_estimators': 100}"
#
# Belt,frequency,1,19,13,18,15,23,0,1,0,2,1,8
#
# [[6220   12]
#  [  88  103]]
# Belt,frequency,2,0.5287958115183246,0.6688741721854304,0.9099099099099099,0.9844309512688775,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Belt,frequency,2,18,21,17,13,21,0,0,0,2,1,7
#
# [[6222   10]
#  [  90  101]]
# Belt,frequency,3,0.4083769633507853,0.5454545454545454,0.8210526315789474,0.979757085020243,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Belt,frequency,3,17,25,28,21,22,1,0,1,0,5,10
#
# [[6214   17]
#  [ 113   78]]
# Belt,frequency,4,0.5287958115183246,0.6579804560260586,0.8706896551724138,0.9836499532855808,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Belt,frequency,4,16,20,12,21,21,0,0,0,0,1,14
#
# [[6216   15]
#  [  90  101]]
# (32117, 72)
# (32117,)
# Belt,time,0,0.5602094240837696,0.6729559748427673,0.84251968503937,0.9838107098381071,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Belt,time,0,17,18,10,14,25,0,0,0,3,3,14
#
# [[6213   20]
#  [  84  107]]
# Belt,time,1,0.6335078534031413,0.7267267267267268,0.852112676056338,0.9858343711083437,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Belt,time,1,13,11,10,14,22,0,1,0,2,1,17
#
# [[6212   21]
#  [  70  121]]
# Belt,time,2,0.5654450261780105,0.6813880126182965,0.8571428571428571,0.9842752607815662,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Belt,time,2,14,13,23,17,16,0,1,0,3,2,12
#
# [[6214   18]
#  [  83  108]]
# Belt,time,3,0.6282722513089005,0.729483282674772,0.8695652173913043,0.9861435466293009,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Belt,time,3,13,18,11,17,12,0,0,1,0,1,16
#
# [[6214   18]
#  [  71  120]]
# Belt,time,4,0.5549738219895288,0.6838709677419355,0.8907563025210085,0.9847423322434999,"{'max_features': 'log2', 'n_estimators': 50}"
#
# Belt,time,4,15,22,17,12,19,0,0,1,0,0,12
#
# [[6219   13]
#  [  85  106]]
# (28324, 540)
# (28324,)
# full,both,0,0.7294117647058823,0.8,0.8857142857142857,0.9890556045895852,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,both,0,11,8,7,6,14,0,1,0,0,0,15
#
# [[5479   16]
#  [  46  124]]
# full,both,1,0.6823529411764706,0.7837837837837838,0.9206349206349206,0.988702559576346,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,both,1,13,7,11,12,11,0,0,0,0,0,10
#
# [[5485   10]
#  [  54  116]]
# full,both,2,0.7235294117647059,0.7961165048543689,0.8848920863309353,0.9888790820829656,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,both,2,9,8,11,5,14,0,1,0,0,0,15
#
# [[5479   16]
#  [  47  123]]
# full,both,3,0.6842105263157895,0.7878787878787878,0.9285714285714286,0.9888790820829656,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# full,both,3,13,10,7,14,10,0,0,0,0,0,9
#
# [[5485    9]
#  [  54  117]]
# full,both,4,0.7176470588235294,0.8215488215488216,0.9606299212598425,0.9906426553672316,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# full,both,4,7,4,7,9,21,0,0,1,0,0,4
#
# [[5489    5]
#  [  48  122]]
# (32113, 36)
# (32113,)
# full,frequency,0,0.39790575916230364,0.5448028673835126,0.8636363636363636,0.9802273081114744,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,frequency,0,20,16,24,20,35,0,1,0,0,3,8
#
# [[6220   12]
#  [ 115   76]]
# full,frequency,1,0.387434554973822,0.5211267605633803,0.7956989247311828,0.9788260937256733,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# full,frequency,1,22,26,28,18,23,2,0,3,0,6,8
#
# [[6213   19]
#  [ 117   74]]
# full,frequency,2,0.36649214659685864,0.5166051660516605,0.875,0.9796045461622295,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,frequency,2,20,24,24,22,31,0,0,0,0,4,6
#
# [[6222   10]
#  [ 121   70]]
# full,frequency,3,0.34554973821989526,0.4943820224719101,0.868421052631579,0.9789785113671753,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# full,frequency,3,25,25,25,18,32,2,0,0,1,2,5
#
# [[6221   10]
#  [ 125   66]]
# full,frequency,4,0.38219895287958117,0.5195729537366548,0.8111111111111111,0.9789785113671753,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# full,frequency,4,17,23,23,22,33,3,1,3,0,6,4
#
# [[6214   17]
#  [ 118   73]]
# (32117, 72)
# (32117,)
# full,time,0,0.46596858638743455,0.615916955017301,0.9081632653061225,0.9827210460772104,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,time,0,16,20,21,13,32,3,0,1,0,0,5
#
# [[6224    9]
#  [ 102   89]]
# full,time,1,0.46596858638743455,0.6267605633802817,0.956989247311828,0.9834993773349938,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,time,1,21,19,18,16,28,0,0,0,0,0,4
#
# [[6229    4]
#  [ 102   89]]
# full,time,2,0.39790575916230364,0.5448028673835126,0.8636363636363636,0.9802273081114744,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# full,time,2,14,29,26,18,28,2,1,0,0,2,7
#
# [[6220   12]
#  [ 115   76]]
# full,time,3,0.46596858638743455,0.6033898305084746,0.8557692307692307,0.9817842129845866,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,time,3,16,17,17,21,31,0,1,0,0,3,11
#
# [[6217   15]
#  [ 102   89]]
# full,time,4,0.46596858638743455,0.6180555555555556,0.9175257731958762,0.9828740463957653,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# full,time,4,16,14,26,16,30,0,0,2,0,4,2
#
# [[6224    8]
#  [ 102   89]]
# (32113, 108)
# (32113,)
# Neck,both,0,0.643979057591623,0.7477203647416414,0.8913043478260869,0.9870776895531683,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Neck,both,0,12,19,12,9,16,0,1,0,1,1,12
#
# [[6217   15]
#  [  68  123]]
# Neck,both,1,0.6387434554973822,0.7439024390243902,0.8905109489051095,0.9869219990658571,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Neck,both,1,8,12,14,15,20,1,1,0,0,2,11
#
# [[6217   15]
#  [  69  122]]
# Neck,both,2,0.612565445026178,0.7027027027027027,0.823943661971831,0.9845866417561887,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Neck,both,2,15,7,15,15,22,0,0,0,2,3,20
#
# [[6207   25]
#  [  74  117]]
# Neck,both,3,0.675392670157068,0.7655786350148368,0.8835616438356164,0.9876985362815323,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Neck,both,3,8,17,10,13,14,0,0,1,0,2,14
#
# [[6214   17]
#  [  62  129]]
# Neck,both,4,0.612565445026178,0.72,0.8731343283582089,0.9858299595141701,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Neck,both,4,10,16,18,9,21,0,1,0,1,1,14
#
# [[6214   17]
#  [  74  117]]
# (32113, 36)
# (32113,)
# Neck,frequency,0,0.5602094240837696,0.6858974358974359,0.8842975206611571,0.9847423322434999,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Neck,frequency,0,13,18,23,9,21,1,0,0,1,5,7
#
# [[6218   14]
#  [  84  107]]
# Neck,frequency,1,0.5078534031413613,0.627831715210356,0.8220338983050848,0.9820955939592091,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Neck,frequency,1,12,18,20,23,21,0,0,1,4,2,14
#
# [[6211   21]
#  [  94   97]]
# Neck,frequency,2,0.518324607329843,0.6387096774193548,0.8319327731092437,0.9825626654211428,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Neck,frequency,2,15,13,20,20,24,0,4,0,2,3,11
#
# [[6212   20]
#  [  92   99]]
# Neck,frequency,3,0.5026178010471204,0.6193548387096774,0.8067226890756303,0.9816256617876051,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Neck,frequency,3,12,16,24,14,29,1,2,0,0,4,16
#
# [[6208   23]
#  [  95   96]]
# Neck,frequency,4,0.5235602094240838,0.6410256410256411,0.8264462809917356,0.9825599501712862,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Neck,frequency,4,14,17,19,14,27,0,1,0,2,5,13
#
# [[6210   21]
#  [  91  100]]
# (32117, 72)
# (32117,)
# Neck,time,0,0.6335078534031413,0.7423312883435583,0.8962962962962963,0.9869240348692403,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Neck,time,0,12,17,15,10,16,0,0,0,2,0,12
#
# [[6219   14]
#  [  70  121]]
# Neck,time,1,0.643979057591623,0.7409638554216867,0.8723404255319149,0.986612702366127,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Neck,time,1,12,16,9,18,13,1,0,0,2,2,13
#
# [[6215   18]
#  [  68  123]]
# Neck,time,2,0.7015706806282722,0.783625730994152,0.8874172185430463,0.9884789039389693,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Neck,time,2,10,9,15,6,17,0,1,0,1,4,11
#
# [[6215   17]
#  [  57  134]]
# Neck,time,3,0.6387434554973822,0.7416413373860182,0.8840579710144928,0.9867663085785459,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# Neck,time,3,7,14,16,12,20,0,0,0,3,0,13
#
# [[6216   16]
#  [  69  122]]
# Neck,time,4,0.5916230366492147,0.6996904024767802,0.8560606060606061,0.9848980227308112,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Neck,time,4,12,16,19,9,22,0,2,1,1,1,14
#
# [[6213   19]
#  [  78  113]]
# (28324, 108)
# (28324,)
# RightPocket,both,0,0.6176470588235294,0.7142857142857143,0.8467741935483871,0.9851721094439541,"{'max_features': 'log2', 'n_estimators': 50}"
#
# RightPocket,both,0,10,13,6,15,21,0,3,1,1,2,12
#
# [[5476   19]
#  [  65  105]]
# RightPocket,both,1,0.5882352941176471,0.7092198581560284,0.8928571428571429,0.9855251544571932,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,both,1,18,18,7,11,16,0,1,0,0,1,10
#
# [[5483   12]
#  [  70  100]]
# RightPocket,both,2,0.5470588235294118,0.6666666666666666,0.8532110091743119,0.9835834068843777,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,both,2,18,13,14,14,18,0,1,0,0,1,14
#
# [[5479   16]
#  [  77   93]]
# RightPocket,both,3,0.6666666666666666,0.7728813559322034,0.9193548387096774,0.9881729920564872,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,both,3,12,17,10,6,12,0,0,0,1,0,9
#
# [[5484   10]
#  [  57  114]]
# RightPocket,both,4,0.6470588235294118,0.7432432432432432,0.873015873015873,0.9865819209039548,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,both,4,10,17,18,10,5,0,1,0,1,3,11
#
# [[5478   16]
#  [  60  110]]
# (28324, 36)
# (28324,)
# RightPocket,frequency,0,0.5411764705882353,0.6715328467153284,0.8846153846153846,0.9841129744042365,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,frequency,0,17,17,13,9,22,0,0,0,1,4,7
#
# [[5483   12]
#  [  78   92]]
# RightPocket,frequency,1,0.5705882352941176,0.6879432624113475,0.8660714285714286,0.9844660194174757,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,frequency,1,11,14,22,13,13,0,1,1,1,5,7
#
# [[5480   15]
#  [  73   97]]
# RightPocket,frequency,2,0.5176470588235295,0.6423357664233577,0.8461538461538461,0.9827007943512798,"{'max_features': 'sqrt', 'n_estimators': 50}"
#
# RightPocket,frequency,2,17,15,9,21,20,0,2,0,5,3,6
#
# [[5479   16]
#  [  82   88]]
# RightPocket,frequency,3,0.5321637426900585,0.6691176470588235,0.900990099009901,0.9841129744042365,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# RightPocket,frequency,3,15,16,12,14,23,0,2,0,0,1,7
#
# [[5484   10]
#  [  80   91]]
# RightPocket,frequency,4,0.5058823529411764,0.6394052044609665,0.8686868686868687,0.9828742937853108,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,frequency,4,25,18,15,13,13,0,0,0,2,2,9
#
# [[5481   13]
#  [  84   86]]
# (28326, 72)
# (28326,)
# RightPocket,time,0,0.6257309941520468,0.740484429065744,0.9067796610169492,0.9867631486057183,"{'max_features': 'log2', 'n_estimators': 100}"
#
# RightPocket,time,0,14,13,14,13,10,0,2,0,2,2,5
#
# [[5484   11]
#  [  64  107]]
# RightPocket,time,1,0.6470588235294118,0.738255033557047,0.859375,0.9862312444836717,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# RightPocket,time,1,9,22,7,12,10,0,3,0,2,1,12
#
# [[5477   18]
#  [  60  110]]
# RightPocket,time,2,0.6,0.6986301369863014,0.8360655737704918,0.9844660194174757,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# RightPocket,time,2,12,19,14,11,12,0,1,1,2,2,14
#
# [[5475   20]
#  [  68  102]]
# RightPocket,time,3,0.5647058823529412,0.6784452296819788,0.8495575221238938,0.9839364518976169,"{'max_features': 'log2', 'n_estimators': 200}"
#
# RightPocket,time,3,13,16,14,11,20,0,1,0,0,0,16
#
# [[5478   17]
#  [  74   96]]
# RightPocket,time,4,0.6176470588235294,0.7473309608540926,0.9459459459459459,0.9874669020300089,"{'max_features': 'log2', 'n_estimators': 200}"
#
# RightPocket,time,4,18,15,9,11,12,0,0,0,0,0,6
#
# [[5489    6]
#  [  65  105]]
# (32113, 108)
# (32113,)
# Wrist,both,0,0.44502617801047123,0.5964912280701754,0.9042553191489362,0.9820955939592091,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,both,0,14,26,17,22,27,0,0,0,0,2,7
#
# [[6223    9]
#  [ 106   85]]
# Wrist,both,1,0.4083769633507853,0.5672727272727273,0.9285714285714286,0.9814728320099642,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,both,1,21,16,18,30,28,0,1,0,0,1,4
#
# [[6226    6]
#  [ 113   78]]
# Wrist,both,2,0.4869109947643979,0.6262626262626263,0.8773584905660378,0.982718355908454,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,both,2,19,21,28,12,18,1,0,0,0,4,8
#
# [[6219   13]
#  [  98   93]]
# Wrist,both,3,0.45549738219895286,0.6,0.8787878787878788,0.9819370912488321,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,both,3,11,19,23,14,37,0,1,2,0,4,5
#
# [[6219   12]
#  [ 104   87]]
# Wrist,both,4,0.4712041884816754,0.6206896551724138,0.9090909090909091,0.9828713796325133,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,both,4,14,19,21,9,38,2,1,0,0,2,4
#
# [[6222    9]
#  [ 101   90]]
# (32113, 36)
# (32113,)
# Wrist,frequency,0,0.41361256544502617,0.5543859649122806,0.8404255319148937,0.9802273081114744,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,frequency,0,22,12,30,21,27,3,1,0,0,5,6
#
# [[6217   15]
#  [ 112   79]]
# Wrist,frequency,1,0.34554973821989526,0.4925373134328358,0.8571428571428571,0.9788260937256733,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,frequency,1,19,28,30,18,30,0,0,0,1,4,6
#
# [[6221   11]
#  [ 125   66]]
# Wrist,frequency,2,0.3717277486910995,0.5201465201465202,0.8658536585365854,0.9796045461622295,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,frequency,2,22,22,24,19,33,2,0,0,0,3,6
#
# [[6221   11]
#  [ 120   71]]
# Wrist,frequency,3,0.38219895287958117,0.5328467153284672,0.8795180722891566,0.9800685144814699,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Wrist,frequency,3,23,23,20,22,30,0,0,2,0,5,3
#
# [[6221   10]
#  [ 118   73]]
# Wrist,frequency,4,0.3507853403141361,0.4908424908424908,0.8170731707317073,0.9783556524447212,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,frequency,4,17,27,20,23,37,0,2,3,0,3,7
#
# [[6216   15]
#  [ 124   67]]
# (32117, 72)
# (32117,)
# Wrist,time,0,0.46596858638743455,0.6137931034482759,0.898989898989899,0.9825653798256538,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Wrist,time,0,19,19,14,15,35,0,0,0,0,2,8
#
# [[6223   10]
#  [ 102   89]]
# Wrist,time,1,0.44502617801047123,0.5882352941176471,0.8673469387755102,0.9814757160647571,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Wrist,time,1,16,22,18,18,32,0,1,1,0,4,7
#
# [[6220   13]
#  [ 106   85]]
# Wrist,time,2,0.46596858638743455,0.6267605633802817,0.956989247311828,0.9834968083450101,"{'max_features': 'sqrt', 'n_estimators': 100}"
#
# Wrist,time,2,14,17,18,23,30,0,1,1,0,1,1
#
# [[6228    4]
#  [ 102   89]]
# Wrist,time,3,0.3769633507853403,0.5294117647058824,0.8888888888888888,0.9800716176241632,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,time,3,20,23,33,14,29,0,0,0,0,2,7
#
# [[6223    9]
#  [ 119   72]]
# Wrist,time,4,0.4973821989528796,0.6354515050167224,0.8796296296296297,0.9830297368830765,"{'max_features': 'sqrt', 'n_estimators': 200}"
#
# Wrist,time,4,15,22,23,15,21,5,2,1,0,2,3
#
# [[6219   13]
#  [  96   95]]
# (32113, 108)
# (32113,)
# Ankle,both,0,0.0,0.0,0.0,0.9699517359489335,"{'hidden_layer_sizes': (16, 128)}"
#
# Ankle,both,0,33,38,32,37,51,0,0,0,1,0,1
#
# [[6230    2]
#  [ 191    0]]
# Ankle,both,1,0.13089005235602094,0.21739130434782608,0.6410256410256411,0.9719757122839795,"{'hidden_layer_sizes': (32, 64)}"
#
# Ankle,both,1,23,38,38,31,36,1,0,0,0,0,13
#
# [[6218   14]
#  [ 166   25]]
# Ankle,both,2,0.47643979057591623,0.5260115606936416,0.5870967741935483,0.974466760080959,"{'hidden_layer_sizes': (32, 16)}"
#
# Ankle,both,2,17,6,29,18,30,29,5,3,1,2,24
#
# [[6168   64]
#  [ 100   91]]
# Ankle,both,3,0.6701570680628273,0.3560500695410292,0.24242424242424243,0.927904079725942,"{'hidden_layer_sizes': (64,)}"
#
# Ankle,both,3,14,6,7,13,23,248,4,5,2,62,79
#
# [[5831  400]
#  [  63  128]]
# C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Ankle,both,4,0.0,0.0,0.0,0.9702584864528184,"{'hidden_layer_sizes': (32, 128)}"
#
# Ankle,both,4,38,28,37,35,53,0,0,0,0,0,0
#
# [[6231    0]
#  [ 191    0]]
# (32113, 36)
# (32113,)
# Ankle,frequency,0,0.5602094240837696,0.34076433121019106,0.2448512585812357,0.9355441382531527,"{'hidden_layer_sizes': (128,)}"
#
# Ankle,frequency,0,13,10,13,21,27,145,1,1,0,53,130
#
# [[5902  330]
#  [  84  107]]
# Ankle,frequency,1,0.03664921465968586,0.0625,0.21212121212121213,0.9673049976646427,"{'hidden_layer_sizes': (16, 16)}"
#
# Ankle,frequency,1,29,40,34,36,45,4,0,2,0,1,19
#
# [[6206   26]
#  [ 184    7]]
# C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Ankle,frequency,2,0.0,0.0,0.0,0.9702631169235559,"{'hidden_layer_sizes': (8, 8)}"
#
# Ankle,frequency,2,28,31,44,35,53,0,0,0,0,0,0
#
# [[6232    0]
#  [ 191    0]]
# Ankle,frequency,3,0.12041884816753927,0.1464968152866242,0.18699186991869918,0.9582684521955777,"{'hidden_layer_sizes': (128, 64)}"
#
# Ankle,frequency,3,38,33,36,28,33,69,0,0,0,0,31
#
# [[6131  100]
#  [ 168   23]]
# Ankle,frequency,4,0.015706806282722512,0.02564102564102564,0.06976744186046512,0.9644970414201184,"{'hidden_layer_sizes': (32, 128)}"
#
# Ankle,frequency,4,35,27,44,33,49,1,0,1,0,2,36
#
# [[6191   40]
#  [ 188    3]]
# (32117, 72)
# (32117,)
# Ankle,time,0,0.41361256544502617,0.4514285714285714,0.4968553459119497,0.9701120797011208,"{'hidden_layer_sizes': (128,)}"
#
# Ankle,time,0,23,16,28,21,24,38,8,9,4,4,17
#
# [[6153   80]
#  [ 112   79]]
# Ankle,time,1,0.005235602094240838,0.010416666666666666,1.0,0.9704234122042341,"{'hidden_layer_sizes': (128, 16)}"
#
# Ankle,time,1,37,25,41,32,55,0,0,0,0,0,0
#
# [[6233    0]
#  [ 190    1]]
# Ankle,time,2,0.581151832460733,0.45962732919254656,0.3801369863013699,0.9593647828117702,"{'hidden_layer_sizes': (16,)}"
#
# Ankle,time,2,16,12,24,8,20,37,3,3,1,50,87
#
# [[6051  181]
#  [  80  111]]
# Ankle,time,3,0.49214659685863876,0.42342342342342343,0.3715415019762846,0.9601432352483263,"{'hidden_layer_sizes': (32,)}"
#
# Ankle,time,3,11,13,22,22,29,89,2,3,1,22,42
#
# [[6073  159]
#  [  97   94]]
# Ankle,time,4,0.09424083769633508,0.15584415584415584,0.45,0.9696403549743111,"{'hidden_layer_sizes': (128,)}"
#
# Ankle,time,4,31,43,32,29,38,0,0,0,2,0,20
#
# [[6210   22]
#  [ 173   18]]
# (32113, 108)
# (32113,)
# Belt,both,0,0.05235602094240838,0.07751937984496124,0.14925373134328357,0.9629456640199284,"{'hidden_layer_sizes': (64,)}"
#
# Belt,both,0,35,34,34,38,40,29,7,0,3,2,16
#
# [[6175   57]
#  [ 181   10]]
# Belt,both,1,0.35602094240837695,0.21621621621621623,0.1552511415525114,0.9232445897555659,"{'hidden_layer_sizes': (64, 32)}"
#
# Belt,both,1,20,26,27,24,26,208,16,28,13,21,84
#
# [[5862  370]
#  [ 123   68]]
# Belt,both,2,0.34554973821989526,0.2037037037037037,0.14442013129102846,0.9196637085474078,"{'hidden_layer_sizes': (64, 32)}"
#
# Belt,both,2,15,20,22,33,35,261,25,32,12,24,37
#
# [[5841  391]
#  [ 125   66]]
# Belt,both,3,0.16753926701570682,0.22377622377622378,0.3368421052631579,0.9654313298037994,"{'hidden_layer_sizes': (32, 16)}"
#
# Belt,both,3,26,26,36,26,45,13,2,17,8,1,22
#
# [[6168   63]
#  [ 159   32]]
# Belt,both,4,0.020942408376963352,0.03980099502487562,0.4,0.9699470569915914,"{'hidden_layer_sizes': (128,)}"
#
# Belt,both,4,33,38,48,30,38,0,0,0,0,0,6
#
# [[6225    6]
#  [ 187    4]]
# (32113, 36)
# (32113,)
# Belt,frequency,0,0.005235602094240838,0.008888888888888889,0.029411764705882353,0.9652810213295968,"{'hidden_layer_sizes': (32, 128)}"
#
# Belt,frequency,0,42,33,37,32,46,2,0,9,0,0,22
#
# [[6199   33]
#  [ 190    1]]
# Belt,frequency,1,0.0,0.0,0.0,0.9683948310758212,"{'hidden_layer_sizes': (128, 16)}"
#
# Belt,frequency,1,24,46,47,35,39,0,0,6,0,0,6
#
# [[6220   12]
#  [ 191    0]]
# Belt,frequency,2,0.02617801047120419,0.03164556962025317,0.04,0.952358710882765,"{'hidden_layer_sizes': (128, 64)}"
#
# Belt,frequency,2,30,35,38,31,52,61,19,10,2,3,25
#
# [[6112  120]
#  [ 186    5]]
# Belt,frequency,3,0.02617801047120419,0.04291845493562232,0.11904761904761904,0.9652756150731859,"{'hidden_layer_sizes': (128, 128)}"
#
# Belt,frequency,3,43,28,38,33,44,16,0,5,0,4,12
#
# [[6194   37]
#  [ 186    5]]
# Belt,frequency,4,0.1518324607329843,0.09555189456342669,0.06971153846153846,0.9145126128931796,"{'hidden_layer_sizes': (128, 128)}"
#
# Belt,frequency,4,29,29,39,25,40,177,10,38,7,112,43
#
# [[5844  387]
#  [ 162   29]]
# (32117, 72)
# (32117,)
# Belt,time,0,0.49214659685863876,0.31333333333333335,0.22982885085574573,0.935865504358655,"{'hidden_layer_sizes': (16,)}"
#
# Belt,time,0,19,17,18,22,21,83,10,13,17,151,41
#
# [[5918  315]
#  [  97   94]]
# Belt,time,1,0.5130890052356021,0.35379061371841153,0.2699724517906336,0.9442714819427148,"{'hidden_layer_sizes': (128,)}"
#
# Belt,time,1,7,22,20,15,29,140,9,25,13,33,45
#
# [[5968  265]
#  [  93   98]]
# Belt,time,2,0.24607329842931938,0.23095823095823095,0.2175925925925926,0.9512688774715865,"{'hidden_layer_sizes': (32, 32)}"
#
# Belt,time,2,19,25,35,26,39,91,21,18,9,17,13
#
# [[6063  169]
#  [ 144   47]]
# Belt,time,3,0.2774869109947644,0.3028571428571429,0.3333333333333333,0.962011521096061,"{'hidden_layer_sizes': (16, 64)}"
#
# Belt,time,3,23,24,29,28,34,59,7,3,10,15,12
#
# [[6126  106]
#  [ 138   53]]
# C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Belt,time,4,0.0,0.0,0.0,0.9702631169235559,"{'hidden_layer_sizes': (32, 16)}"
#
# Belt,time,4,34,34,47,35,41,0,0,0,0,0,0
#
# [[6232    0]
#  [ 191    0]]
# (28324, 540)
# (28324,)
# full,both,0,0.4588235294117647,0.5909090909090909,0.8297872340425532,0.9809355692850839,"{'hidden_layer_sizes': (16,)}"
#
# full,both,0,24,13,12,16,27,1,0,1,4,2,8
#
# [[5479   16]
#  [  92   78]]
# C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# full,both,1,0.0,0.0,0.0,0.969991173874669,"{'hidden_layer_sizes': (64, 16)}"
#
# full,both,1,28,28,38,36,40,0,0,0,0,0,0
#
# [[5495    0]
#  [ 170    0]]
# full,both,2,0.611764705882353,0.6624203821656051,0.7222222222222222,0.981288614298323,"{'hidden_layer_sizes': (32,)}"
#
# full,both,2,7,9,17,12,21,11,7,3,4,2,13
#
# [[5455   40]
#  [  66  104]]
# full,both,3,0.6374269005847953,0.6855345911949685,0.7414965986394558,0.9823477493380406,"{'hidden_layer_sizes': (32,)}"
#
# full,both,3,7,16,11,11,17,18,4,2,1,0,13
#
# [[5456   38]
#  [  62  109]]
# full,both,4,0.0,0.0,0.0,0.9698093220338984,"{'hidden_layer_sizes': (128, 32)}"
#
# full,both,4,39,26,37,25,43,0,0,0,1,0,0
#
# [[5493    1]
#  [ 170    0]]
# (32113, 36)
# (32113,)
# full,frequency,0,0.0,0.0,0.0,0.9690175930250662,"{'hidden_layer_sizes': (16, 8)}"
#
# full,frequency,0,33,35,45,31,47,0,1,1,0,0,6
#
# [[6224    8]
#  [ 191    0]]
# full,frequency,1,0.6178010471204188,0.14106395696353854,0.0796221322537112,0.7762727697337692,"{'hidden_layer_sizes': (64, 32)}"
#
# full,frequency,1,21,18,13,15,6,483,196,133,22,345,185
#
# [[4868 1364]
#  [  73  118]]
# full,frequency,2,0.2931937172774869,0.2309278350515464,0.19047619047619047,0.941927448232913,"{'hidden_layer_sizes': (128,)}"
#
# full,frequency,2,19,30,28,23,35,124,22,10,3,35,44
#
# [[5994  238]
#  [ 135   56]]
# C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# full,frequency,3,0.0,0.0,0.0,0.9702584864528184,"{'hidden_layer_sizes': (8, 32)}"
#
# full,frequency,3,35,21,45,34,56,0,0,0,0,0,0
#
# [[6231    0]
#  [ 191    0]]
# full,frequency,4,0.05235602094240838,0.08333333333333333,0.20408163265306123,0.9657427592650265,"{'hidden_layer_sizes': (128,)}"
#
# full,frequency,4,33,38,36,34,40,3,7,6,0,1,22
#
# [[6192   39]
#  [ 181   10]]
# (32117, 72)
# (32117,)
# full,time,0,0.05759162303664921,0.10091743119266056,0.4074074074074074,0.9694894146948941,"{'hidden_layer_sizes': (128, 128)}"
#
# ...
#
# Ankle,time,1,5,7,13,11,13,396,19,12,27,278,57
#
# [[5444  789]
#  [  49  142]]
# Ankle,time,2,0.7539267015706806,0.25622775800711745,0.15434083601286175,0.8698427526078156,"{'class_weight': {0: 1, 1: 20}}"
#
# Ankle,time,2,9,8,11,5,14,356,22,12,20,332,47
#
# [[5443  789]
#  [  47  144]]
# Ankle,time,3,0.7591623036649214,0.26508226691042047,0.16057585825027684,0.8748248482017749,"{'class_weight': {0: 1, 1: 20}}"
#
# Ankle,time,3,3,8,12,8,15,379,22,18,19,275,45
#
# [[5474  758]
#  [  46  145]]
# Ankle,time,4,0.7015706806282722,0.2635201573254671,0.162227602905569,0.8833878250038922,"{'class_weight': {0: 1, 1: 20}}"
#
# Ankle,time,4,11,8,10,7,21,353,13,9,7,270,40
#
# [[5540  692]
#  [  57  134]]
# (32113, 108)
# (32113,)
# Belt,both,0,0.5968586387434555,0.24918032786885247,0.1574585635359116,0.8930406352171882,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,both,0,15,16,15,15,16,309,7,7,9,261,17
#
# [[5622  610]
#  [  77  114]]
# Belt,both,1,0.7015706806282722,0.27543679342240496,0.17135549872122763,0.8902382064455862,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,both,1,18,11,8,10,10,359,9,9,14,233,24
#
# [[5584  648]
#  [  57  134]]
# Belt,both,2,0.7120418848167539,0.2851153039832285,0.1782437745740498,0.8938190876537444,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,both,2,10,6,16,5,18,316,10,6,9,255,31
#
# [[5605  627]
#  [  55  136]]
# Belt,both,3,0.5863874345549738,0.24374319912948858,0.15384615384615385,0.8917782622236063,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,both,3,15,11,20,13,20,307,6,8,12,254,29
#
# [[5615  616]
#  [  79  112]]
# Belt,both,4,0.6335078534031413,0.2639040348964013,0.16666666666666666,0.8948925568358767,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,both,4,9,24,11,9,17,310,5,11,11,253,15
#
# [[5626  605]
#  [  70  121]]
# (32113, 36)
# (32113,)
# Belt,frequency,0,0.6492146596858639,0.26495726495726496,0.16644295302013423,0.892884944729877,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,frequency,0,8,14,16,11,18,322,4,7,11,262,15
#
# [[5611  621]
#  [  67  124]]
# Belt,frequency,1,0.6387434554973822,0.2592986184909671,0.16266666666666665,0.891483730344076,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,frequency,1,9,13,16,12,19,315,5,10,8,262,28
#
# [[5604  628]
#  [  69  122]]
# Belt,frequency,2,0.6387434554973822,0.2646420824295011,0.16689466484268126,0.8944418496029892,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,frequency,2,11,13,9,18,18,331,8,7,10,234,19
#
# [[5623  609]
#  [  69  122]]
# Belt,frequency,3,0.6492146596858639,0.26609442060085836,0.16734143049932523,0.893491124260355,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,frequency,3,20,11,15,4,17,313,10,8,12,242,32
#
# [[5614  617]
#  [  67  124]]
# Belt,frequency,4,0.6335078534031413,0.250258531540848,0.1559278350515464,0.8871068203052008,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,frequency,4,18,16,15,10,11,328,10,10,15,268,24
#
# [[5576  655]
#  [  70  121]]
# (32117, 72)
# (32117,)
# Belt,time,0,0.6335078534031413,0.27039106145251396,0.171875,0.8983499377334994,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,time,0,8,13,15,15,19,336,9,7,14,195,22
#
# [[5650  583]
#  [  70  121]]
# Belt,time,1,0.6492146596858639,0.2834285714285714,0.18128654970760233,0.9023972602739726,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,time,1,18,10,16,8,15,287,7,11,11,219,25
#
# [[5673  560]
#  [  67  124]]
# Belt,time,2,0.5706806282722513,0.2576832151300236,0.166412213740458,0.9022263739685505,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,time,2,18,15,17,10,22,298,8,8,9,200,23
#
# [[5686  546]
#  [  82  109]]
# Belt,time,3,0.675392670157068,0.30424528301886794,0.1963470319634703,0.9081426124863771,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,time,3,9,14,13,9,17,279,7,6,8,207,21
#
# [[5704  528]
#  [  62  129]]
# Belt,time,4,0.680628272251309,0.3151515151515151,0.20504731861198738,0.9120348746691577,"{'class_weight': {0: 1, 1: 20}}"
#
# Belt,time,4,15,14,9,11,12,264,9,10,11,185,25
#
# [[5728  504]
#  [  61  130]]
# (28324, 540)
# (28324,)
# full,both,0,0.8,0.5322896281800391,0.39882697947214074,0.957811120917917,"{'class_weight': {0: 1, 1: 20}}"
#
# full,both,0,3,4,8,10,9,21,8,6,24,111,35
#
# [[5290  205]
#  [  34  136]]
# full,both,1,0.7294117647058823,0.5,0.3803680981595092,0.9562224183583407,"{'class_weight': {0: 1, 1: 20}}"
#
# full,both,1,7,9,10,13,7,25,12,4,27,95,39
#
# [[5293  202]
#  [  46  124]]
# full,both,2,0.7352941176470589,0.4816955684007707,0.35816618911174786,0.9525154457193292,"{'class_weight': {0: 1, 1: 20}}"
#
# full,both,2,6,9,11,14,5,38,17,3,23,125,18
#
# [[5271  224]
#  [  45  125]]
# full,both,3,0.7076023391812866,0.5159914712153518,0.40604026845637586,0.9599293909973522,"{'class_weight': {0: 1, 1: 20}}"
#
# full,both,3,7,14,12,7,10,21,11,3,28,98,16
#
# [[5317  177]
#  [  50  121]]
# full,both,4,0.8,0.5517241379310345,0.42105263157894735,0.960981638418079,"{'class_weight': {0: 1, 1: 20}}"
#
# full,both,4,8,6,10,5,5,27,11,5,28,92,24
#
# [[5307  187]
#  [  34  136]]
# (32113, 36)
# (32113,)
# full,frequency,0,0.5863874345549738,0.27053140096618356,0.17582417582417584,0.9059629456640199,"{'class_weight': {0: 1, 1: 20}}"
#
# full,frequency,0,8,12,23,16,20,258,48,28,8,137,46
#
# [[5707  525]
#  [  79  112]]
# full,frequency,1,0.6230366492146597,0.2982456140350877,0.19604612850082373,0.9128133271057138,"{'class_weight': {0: 1, 1: 20}}"
#
# full,frequency,1,14,13,16,9,20,221,48,24,8,144,43
#
# [[5744  488]
#  [  72  119]]
# full,frequency,2,0.581151832460733,0.24611973392461198,0.15611814345991562,0.8941304686283668,"{'class_weight': {0: 1, 1: 20}}"
#
# full,frequency,2,13,17,18,13,19,262,62,36,6,166,68
#
# [[5632  600]
#  [  80  111]]
# full,frequency,3,0.6387434554973822,0.2807825086306099,0.17994100294985252,0.9026782933665525,"{'class_weight': {0: 1, 1: 20}}"
#
# full,frequency,3,9,11,18,15,16,246,60,30,4,166,50
#
# [[5675  556]
#  [  69  122]]
# full,frequency,4,0.5916230366492147,0.2530795072788354,0.16096866096866097,0.8961382746807848,"{'class_weight': {0: 1, 1: 20}}"
#
# full,frequency,4,11,14,16,13,24,273,62,33,5,158,58
#
# [[5642  589]
#  [  78  113]]
# (32117, 72)
# (32117,)
# full,time,0,0.5497382198952879,0.26854219948849106,0.17766497461928935,0.910958904109589,"{'class_weight': {0: 1, 1: 20}}"
#
# full,time,0,13,13,20,12,28,207,54,25,7,147,46
#
# [[5747  486]
#  [  86  105]]
# full,time,1,0.4869109947643979,0.24866310160427807,0.16696588868940754,0.9125155666251556,"{'class_weight': {0: 1, 1: 20}}"
#
# full,time,1,16,19,17,21,25,186,58,37,8,121,54
#
# [[5769  464]
#  [  98   93]]
# full,time,2,0.5287958115183246,0.2718707940780619,0.18297101449275363,0.9157714463646272,"{'class_weight': {0: 1, 1: 20}}"
#
# full,time,2,6,11,28,15,30,188,47,34,6,124,52
#
# [[5781  451]
#  [  90  101]]
# full,time,3,0.5287958115183246,0.2774725274725275,0.18808193668528864,0.9181068036742955,"{'class_weight': {0: 1, 1: 20}}"
#
# full,time,3,17,19,20,16,18,183,55,22,8,128,40
#
# [[5796  436]
#  [  90  101]]
# full,time,4,0.643979057591623,0.3166023166023166,0.2098976109215017,0.9173283512377394,"{'class_weight': {0: 1, 1: 20}}"
#
# full,time,4,3,11,21,12,21,189,41,26,9,143,55
#
# [[5769  463]
#  [  68  123]]
# (32113, 108)
# (32113,)
# Neck,both,0,0.7591623036649214,0.30687830687830686,0.19230769230769232,0.8980227308111475,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,both,0,5,7,10,16,8,66,27,7,34,428,47
#
# [[5623  609]
#  [  46  145]]
# Neck,both,1,0.7591623036649214,0.3017689906347555,0.18831168831168832,0.8955316830141679,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,both,1,4,8,8,11,15,55,22,12,29,459,48
#
# [[5607  625]
#  [  46  145]]
# Neck,both,2,0.774869109947644,0.30421377183967113,0.18925831202046037,0.8945975400903005,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,both,2,9,7,16,5,6,69,15,11,33,467,39
#
# [[5598  634]
#  [  43  148]]
# Neck,both,3,0.7696335078534031,0.29080118694362017,0.17926829268292682,0.888352538150109,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,both,3,7,12,13,7,5,76,30,6,27,471,63
#
# [[5558  673]
#  [  44  147]]
# Neck,both,4,0.7539267015706806,0.29844559585492225,0.18604651162790697,0.8945811273746497,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,both,4,8,12,11,8,8,84,27,9,35,427,48
#
# [[5601  630]
#  [  47  144]]
# (32113, 36)
# (32113,)
# Neck,frequency,0,0.7643979057591623,0.2985685071574642,0.1855146124523507,0.8931963257044995,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,frequency,0,8,8,12,8,9,75,20,8,23,455,60
#
# [[5591  641]
#  [  45  146]]
# Neck,frequency,1,0.7853403141361257,0.3115264797507788,0.19430051813471502,0.8967772069126576,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,frequency,1,5,4,16,10,6,59,31,9,27,456,40
#
# [[5610  622]
#  [  41  150]]
# Neck,frequency,2,0.7539267015706806,0.2947799385875128,0.183206106870229,0.8927292542425658,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,frequency,2,9,13,14,6,5,70,16,16,37,450,53
#
# [[5590  642]
#  [  47  144]]
# Neck,frequency,3,0.7382198952879581,0.29012345679012347,0.18053777208706787,0.8925568358766739,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,frequency,3,6,10,9,15,10,65,23,7,36,460,49
#
# [[5591  640]
#  [  50  141]]
# Neck,frequency,4,0.7591623036649214,0.29263370332996974,0.18125,0.8908439738399253,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,frequency,4,5,11,8,11,11,84,30,5,33,459,44
#
# [[5576  655]
#  [  46  145]]
# (32117, 72)
# (32117,)
# Neck,time,0,0.7277486910994765,0.31917336394948337,0.20441176470588235,0.9076899128268991,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,time,0,7,11,9,16,9,50,25,13,42,362,49
#
# [[5692  541]
#  [  52  139]]
# Neck,time,1,0.7801047120418848,0.32603938730853393,0.20608575380359612,0.9041095890410958,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,time,1,6,7,11,6,12,59,22,14,29,398,52
#
# [[5659  574]
#  [  42  149]]
# Neck,time,2,0.7486910994764397,0.32873563218390806,0.2106038291605302,0.9090767554102445,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,time,2,8,13,9,8,10,46,20,9,26,376,59
#
# [[5696  536]
#  [  48  143]]
# Neck,time,3,0.8010471204188482,0.34,0.2157968970380818,0.9075198505371321,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,time,3,4,7,15,8,4,55,24,6,33,386,52
#
# [[5676  556]
#  [  38  153]]
# Neck,time,4,0.743455497382199,0.32054176072234764,0.20431654676258992,0.9062743266386424,"{'class_weight': {0: 1, 1: 20}}"
#
# Neck,time,4,4,9,15,12,9,43,26,7,33,385,59
#
# [[5679  553]
#  [  49  142]]
# (28324, 108)
# (28324,)
# RightPocket,both,0,0.6941176470588235,0.35066864784546803,0.2345924453280318,0.9228596646072375,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,both,0,14,18,12,3,5,139,24,8,22,167,25
#
# [[5110  385]
#  [  52  118]]
# RightPocket,both,1,0.6823529411764706,0.3729903536977492,0.25663716814159293,0.9311562224183584,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,both,1,16,13,10,6,9,132,19,7,22,138,18
#
# [[5159  336]
#  [  54  116]]
# RightPocket,both,2,0.711764705882353,0.36390977443609024,0.24444444444444444,0.9253309796999117,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,both,2,13,12,7,6,11,124,27,12,24,166,21
#
# [[5121  374]
#  [  49  121]]
# RightPocket,both,3,0.672514619883041,0.36106750392464676,0.24678111587982832,0.9281553398058252,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,both,3,11,11,8,13,13,138,21,8,22,143,19
#
# [[5143  351]
#  [  56  115]]
# RightPocket,both,4,0.7294117647058823,0.38212634822804314,0.2588726513569937,0.92920197740113,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,both,4,14,9,7,10,6,115,31,5,22,155,27
#
# [[5139  355]
#  [  46  124]]
# (28324, 36)
# (28324,)
# RightPocket,frequency,0,0.6823529411764706,0.34421364985163205,0.23015873015873015,0.9219770520741395,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,frequency,0,17,12,7,10,8,135,22,4,17,181,29
#
# [[5107  388]
#  [  54  116]]
# RightPocket,frequency,1,0.6647058823529411,0.3639291465378422,0.25055432372505543,0.9302736098852604,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,frequency,1,18,11,13,6,9,116,25,15,26,137,19
#
# [[5157  338]
#  [  57  113]]
# RightPocket,frequency,2,0.7411764705882353,0.36258992805755397,0.24,0.9218005295675199,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,frequency,2,12,10,7,6,9,166,27,9,18,159,20
#
# [[5096  399]
#  [  44  126]]
# RightPocket,frequency,3,0.7076023391812866,0.3896940418679549,0.2688888888888889,0.9330979699911739,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,frequency,3,12,17,5,9,7,116,15,5,27,143,23
#
# [[5165  329]
#  [  50  121]]
# RightPocket,frequency,4,0.6882352941176471,0.34011627906976744,0.22586872586872586,0.9198446327683616,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,frequency,4,10,15,10,8,10,150,26,6,22,177,20
#
# [[5093  401]
#  [  53  117]]
# (28326, 72)
# (28326,)
# RightPocket,time,0,0.5789473684210527,0.35934664246823955,0.26052631578947366,0.9376985527709142,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,time,0,11,22,14,14,11,82,14,12,23,128,22
#
# [[5214  281]
#  [  72   99]]
# RightPocket,time,1,0.7,0.371875,0.2531914893617021,0.9290379523389232,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,time,1,6,11,16,10,8,121,21,22,21,141,25
#
# [[5144  351]
#  [  51  119]]
# RightPocket,time,2,0.6941176470588235,0.4054982817869416,0.28640776699029125,0.9389232127096204,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,time,2,11,11,8,8,14,119,22,11,22,97,23
#
# [[5201  294]
#  [  52  118]]
# RightPocket,time,3,0.6,0.35978835978835977,0.25692695214105793,0.9359223300970874,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,time,3,19,13,9,15,12,111,25,5,28,100,26
#
# [[5200  295]
#  [  68  102]]
# RightPocket,time,4,0.6882352941176471,0.39593908629441626,0.27790973871733965,0.9369814651368049,"{'class_weight': {0: 1, 1: 20}}"
#
# RightPocket,time,4,16,12,7,5,13,88,28,12,25,135,16
#
# [[5191  304]
#  [  53  117]]
# (32113, 108)
# (32113,)
# Wrist,both,0,0.6020942408376964,0.27413587604290823,0.17746913580246915,0.9051844932274637,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,both,0,7,12,21,11,25,227,58,34,6,170,38
#
# [[5699  533]
#  [  76  115]]
# Wrist,both,1,0.5916230366492147,0.25251396648044694,0.16051136363636365,0.8958430639887903,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,both,1,13,16,16,15,18,264,62,31,6,174,54
#
# [[5641  591]
#  [  78  113]]
# Wrist,both,2,0.6596858638743456,0.27661909989023054,0.175,0.8973999688619025,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,both,2,5,11,16,14,19,274,50,35,4,174,57
#
# [[5638  594]
#  [  65  126]]
# Wrist,both,3,0.6335078534031413,0.2965686274509804,0.1936,0.9106197446278418,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,both,3,13,9,14,13,21,240,67,21,4,114,58
#
# [[5727  504]
#  [  70  121]]
# Wrist,both,4,0.5445026178010471,0.2549019607843137,0.1664,0.9053254437869822,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,both,4,18,17,23,11,18,254,48,31,8,127,53
#
# [[5710  521]
#  [  87  104]]
# (32113, 36)
# (32113,)
# Wrist,frequency,0,0.643979057591623,0.28771929824561404,0.1852409638554217,0.9051844932274637,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,frequency,0,9,16,17,11,15,262,58,29,6,133,53
#
# [[5691  541]
#  [  68  123]]
# Wrist,frequency,1,0.6492146596858639,0.28604382929642447,0.1834319526627219,0.9036275883543515,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,frequency,1,7,13,16,13,18,250,68,23,5,154,52
#
# [[5680  552]
#  [  67  124]]
# Wrist,frequency,2,0.5759162303664922,0.25,0.15965166908563136,0.8972442783745913,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,frequency,2,15,16,20,11,19,275,59,33,4,157,51
#
# [[5653  579]
#  [  81  110]]
# Wrist,frequency,3,0.5863874345549738,0.26229508196721313,0.1689291101055807,0.9018997197134849,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,frequency,3,11,14,18,21,15,248,44,35,6,172,46
#
# [[5680  551]
#  [  79  112]]
# Wrist,frequency,4,0.6073298429319371,0.2669735327963176,0.1710914454277286,0.9008097165991903,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,frequency,4,10,7,20,9,29,254,53,28,9,164,54
#
# [[5669  562]
#  [  75  116]]
# (32117, 72)
# (32117,)
# Wrist,time,0,0.5130890052356021,0.24968152866242038,0.16498316498316498,0.9083125778331258,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,time,0,11,13,15,22,32,191,50,41,8,149,57
#
# [[5737  496]
#  [  93   98]]
# Wrist,time,1,0.5445026178010471,0.2769640479360852,0.18571428571428572,0.9154732254047323,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,time,1,10,11,28,13,25,200,48,29,11,112,56
#
# [[5777  456]
#  [  87  104]]
# Wrist,time,2,0.5287958115183246,0.2650918635170604,0.17688266199649738,0.9128133271057138,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,time,2,18,12,22,15,23,207,59,27,9,124,44
#
# [[5762  470]
#  [  90  101]]
# Wrist,time,3,0.5549738219895288,0.2782152230971129,0.18563922942206654,0.914370231978826,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,time,3,8,22,23,16,16,186,58,27,9,138,47
#
# [[5767  465]
#  [  85  106]]
# Wrist,time,4,0.6073298429319371,0.31266846361185985,0.21052631578947367,0.9205978514712752,"{'class_weight': {0: 1, 1: 20}}"
#
# Wrist,time,4,11,13,19,12,20,181,41,18,5,139,51
#
# [[5797  435]
#  [  75  116]]

# %%
len(classifier.best_estimator_.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 len(classifier.best_estimator_.feature_importances_)
#
# AttributeError: 'SVC' object has no attribute 'feature_importances_'
